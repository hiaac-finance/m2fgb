# %%
import sys
sys.path.append("../scripts")

import data
import utils
import models
import experiments

import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import optuna

# %%
dataset = "german"
alpha = 0.5
model_name = "FairGBMClassifier"

args = {
    "dataset": dataset,
    "alpha": alpha,
    "output_dir": f"../results/subgroup_experiment/{dataset}/{model_name}_{alpha}_thresh_05",
    "model_name": model_name,
    "n_trials": 100,
    "n_groups": 4,
    "thresh" : 0.5
    
}
experiments.run_subgroup_experiment(args)
# Out:
#  30%|█████████████████████████████████████████████████▌                                                                                                                   | 3/10 [00:28<01:03,  9.02s/it]/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
#  40%|██████████████████████████████████████████████████████████████████                                                                                                   | 4/10 [00:36<00:53,  8.85s/it]/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# ...

# %%
dataset = "adult"
alpha = 0.5
model_name = "FairGBMClassifier"

args = {
    "dataset": dataset,
    "alpha": alpha,
    "output_dir": f"../results/subgroup_experiment/{dataset}/{model_name}_{alpha}_thresh_05",
    "model_name": model_name,
    "n_trials": 100,
    "n_groups": 4,
    "thresh" : 0.5
    
}
experiments.run_subgroup_experiment(args)
# Out:
#  20%|█████████████████████▍                                                                                     | 2/10 [01:20<04:56, 37.02s/it]/usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#  50%|█████████████████████████████████████████████████████▌                                                     | 5/10 [03:15<03:10, 38.16s/it]/usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [07:07<00:00, 42.73s/it]

# %%
dataset = "german"
alpha = 0.5
model_name = "FairGBMClassifier"

args = {
    "dataset": dataset,
    "alpha": alpha,
    "output_dir": f"../results/subgroup_experiment/{dataset}/{model_name}_{alpha}_thresh_ks",
    "model_name": model_name,
    "n_trials": 100,
    "n_groups": 4,
    "thresh" : "ks"
    
}
experiments.run_subgroup_experiment(args)
# Out:
#  30%|████████████████████████████████                                                                           | 3/10 [00:33<01:12, 10.30s/it]/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
#  40%|██████████████████████████████████████████▊                                                                | 4/10 [00:43<01:00, 10.11s/it]/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:2458: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# ...

# %%
dataset = "adult"
alpha = 0.5
model_name = "FairGBMClassifier"

args = {
    "dataset": dataset,
    "alpha": alpha,
    "output_dir": f"../results/subgroup_experiment/{dataset}/{model_name}_{alpha}_thresh_ks",
    "model_name": model_name,
    "n_trials": 100,
    "n_groups": 4,
    "thresh" : "ks"
    
}
experiments.run_subgroup_experiment(args)
# Out:
#  20%|█████████████████████▍                                                                                     | 2/10 [02:05<08:45, 65.64s/it]/usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#  50%|█████████████████████████████████████████████████████▌                                                     | 5/10 [06:14<07:02, 84.53s/it]/usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:241: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [11:14<00:00, 67.44s/it]

# %%
model_name = "FairGBMClassifier"
alpha = 0.5
print(f"Model={model_name}, alpha={alpha}")
for dataset in ["german", "adult"]:
    print(f"Results for {dataset}")
    for thresh in ["05", "ks"]:
        df = pd.read_csv(f"../results/subgroup_experiment/{dataset}/{model_name}_{alpha}_thresh_{thresh}/results.csv")

        if thresh == "05":
            print(f"Threshold: 0.5")

        else:
            print(f"Threshold: KS")

        print(f"\tMean bal_acc: {df['bal_acc'].mean():.3f} +- {df['bal_acc'].std():.3f}")
        print(f"\tMean eod: {df['eod'].abs().mean():.3f} +- {df['eod'].abs().std():.3f}")
# Out:
# Model=FairGBMClassifier, alpha=0.5
# Results for german
# Threshold: 0.5
# 	Mean bal_acc: 0.617 +- 0.079
# 	Mean eod: 0.227 +- 0.240
# Threshold: KS
# 	Mean bal_acc: 0.625 +- 0.086
# 	Mean eod: 0.358 +- 0.290
# Results for adult
# Threshold: 0.5
# 	Mean bal_acc: 0.781 +- 0.015
# 	Mean eod: 0.134 +- 0.055
# Threshold: KS
# 	Mean bal_acc: 0.831 +- 0.007
# 	Mean eod: 0.123 +- 0.052
